# %%
from keras.models import load_model
import cv2
import numpy as np

# %%
model = load_model('model-007.model')

face_clsfr=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

source=cv2.VideoCapture(0)

labels_dict={0:'MASK',1:'NO MASK'}
color_dict={0:(0,255,0),1:(0,0,255)}

# %%
# import winsound
import pyautogui

while(True):

    ret,img=source.read()
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=face_clsfr.detectMultiScale(gray,1.3,5)  

    for (x,y,w,h) in faces:
    
        face_img=gray[y:y+w,x:x+w]
        resized=cv2.resize(face_img,(100,100))
        normalized=resized/255.0
        reshaped=np.reshape(normalized,(1,100,100,1))
        result=model.predict(reshaped)

        label=np.argmax(result,axis=1)[0]
        if(label==1):
            pyautogui.alert("please wear mask")
            break
                
#         if(label==1):
#             winsound.Beep(440, 500)
        if(label==1):
            print("no_mask")
        else:
            print("mask")
                          
        cv2.rectangle(img,(x,y),(x+w,y+h),color_dict[label],2)
        cv2.rectangle(img,(x,y-40),(x+w,y),color_dict[label],-1)
        cv2.putText(img, labels_dict[label], (x, y-10),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)
        
        
    cv2.imshow('LIVE',img)
    key=cv2.waitKey(1)
    
    if(key==27):
        break
        
cv2.destroyAllWindows()
source.release()
# Out:
# 1/1 [==============================] - 0s 491ms/step
# no_mask
# 1/1 [==============================] - 0s 53ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 50ms/step
# mask
# 1/1 [==============================] - 0s 38ms/step
# mask
# 1/1 [==============================] - 0s 46ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 39ms/step
# mask
# 1/1 [==============================] - 0s 63ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 58ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 52ms/step
# mask
# 1/1 [==============================] - 0s 42ms/step
# mask
# 1/1 [==============================] - 0s 50ms/step
# mask
# 1/1 [==============================] - 0s 54ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 48ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 46ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 56ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 52ms/step
# mask
# 1/1 [==============================] - 0s 43ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 49ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 31ms/step
# mask
# 1/1 [==============================] - 0s 53ms/step
# mask
# 1/1 [==============================] - 0s 53ms/step
# mask
# 1/1 [==============================] - 0s 49ms/step
# mask
# 1/1 [==============================] - 0s 45ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 39ms/step
# mask
# 1/1 [==============================] - 0s 59ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 38ms/step
# mask
# 1/1 [==============================] - 0s 51ms/step
# mask
# 1/1 [==============================] - 0s 42ms/step
# mask
# 1/1 [==============================] - 0s 52ms/step
# mask
# 1/1 [==============================] - 0s 53ms/step
# mask
# 1/1 [==============================] - 0s 31ms/step
# no_mask
# 1/1 [==============================] - 0s 34ms/step
# no_mask
# 1/1 [==============================] - 0s 47ms/step
# no_mask
# 1/1 [==============================] - 0s 47ms/step
# no_mask
# 1/1 [==============================] - 0s 38ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 52ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 38ms/step
# no_mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 35ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 50ms/step
# mask
# 1/1 [==============================] - 0s 31ms/step
# mask
# 1/1 [==============================] - 0s 40ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 57ms/step
# mask
# 1/1 [==============================] - 0s 43ms/step
# mask
# 1/1 [==============================] - 0s 53ms/step
# mask
# 1/1 [==============================] - 0s 45ms/step
# mask
# 1/1 [==============================] - 0s 31ms/step
# mask
# 1/1 [==============================] - 0s 40ms/step
# mask
# 1/1 [==============================] - 0s 44ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 40ms/step
# mask
# 1/1 [==============================] - 0s 36ms/step
# mask
# 1/1 [==============================] - 0s 46ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 49ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 53ms/step
# mask
# 1/1 [==============================] - 0s 47ms/step
# mask
# 1/1 [==============================] - 0s 31ms/step
# no_mask
# 1/1 [==============================] - 0s 47ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#      18         label=np.argmax(result,axis=1)[0]
#      19         if(label==1):
# ---> 20             pyautogui.alert("please wear mask")
#      21 #         if(label==1):
#      22 #             winsound.Beep(440, 500)
#      23         if(label==1):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymsgbox\_native_win.py:69, in alert(text, title, button, root, timeout, icon, _tkinter)
#      64 if (_tkinter) or (timeout is not None) or (button != pymsgbox.OK_TEXT):
#      65     # Timeouts are not supported by Windows message boxes.
#      66     # Call the original tkinter alert function, not this native one:
#      67     return pymsgbox._alertTkinter(text, title, button, root, timeout)
# ---> 69 messageBoxFunc(0, text, title, MB_OK | MB_SETFOREGROUND | MB_TOPMOST | icon)
#      70 return button
#
# KeyboardInterrupt:
